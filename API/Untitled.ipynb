# %%
import requests

url = "https://api.apilayer.com/exchangerates_data"

payload = {}
headers= {
  "apikey": "FKSr0Stmun5DUCxc4Fd1XLk83FNEVARY"
}

response = requests.request("GET", url, headers=headers, data = payload)

status_code = response.status_code
result = response.text

# %%
status_code
# Out:
# 200

# %% [raw]
# result

# %%
result
# Out:
# '{\n    "success": true,\n    "timestamp": 1674576723,\n    "base": "EUR",\n    "date": "2023-01-24",\n    "rates": {\n        "AED": 3.995122,\n        "AFN": 97.345406,\n        "ALL": 116.254359,\n        "AMD": 431.150732,\n        "ANG": 1.960437,\n        "AOA": 547.296249,\n        "ARS": 200.887962,\n        "AUD": 1.544137,\n        "AWG": 1.957842,\n        "AZN": 1.850545,\n        "BAM": 1.957702,\n        "BBD": 2.19626,\n        "BDT": 115.953063,\n        "BGN": 1.958772,\n        "BHD": 0.410068,\n        "BIF": 2243.360538,\n        "BMD": 1.08769,\n        "BND": 1.435312,\n        "BOB": 7.516294,\n        "BRL": 5.606386,\n        "BSD": 1.08777,\n        "BTC": 4.7518463e-05,\n        "BTN": 88.824577,\n        "BWP": 13.927665,\n        "BYN": 2.745525,\n        "BYR": 21318.723176,\n        "BZD": 2.192496,\n        "CAD": 1.453399,\n        "CDF": 2218.88713,\n        "CHF": 1.005156,\n        "CLF": 0.031624,\n        "CLP": 872.978202,\n        "CNY": 7.3794
# ...

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1674576723,
#  'base': 'EUR',
#  'date': '2023-01-24',
#  'rates': {'AED': 3.995122,
#   'AFN': 97.345406,
#   'ALL': 116.254359,
#   'AMD': 431.150732,
#   'ANG': 1.960437,
#   'AOA': 547.296249,
#   'ARS': 200.887962,
#   'AUD': 1.544137,
#   'AWG': 1.957842,
#   'AZN': 1.850545,
#   'BAM': 1.957702,
#   'BBD': 2.19626,
#   'BDT': 115.953063,
#   'BGN': 1.958772,
#   'BHD': 0.410068,
#   'BIF': 2243.360538,
#   'BMD': 1.08769,
#   'BND': 1.435312,
#   'BOB': 7.516294,
#   'BRL': 5.606386,
#   'BSD': 1.08777,
#   'BTC': 4.7518463e-05,
#   'BTN': 88.824577,
#   'BWP': 13.927665,
#   'BYN': 2.745525,
#   'BYR': 21318.723176,
#   'BZD': 2.192496,
#   'CAD': 1.453399,
#   'CDF': 2218.88713,
#   'CHF': 1.005156,
#   'CLF': 0.031624,
#   'CLP': 872.978202,
#   'CNY': 7.379435,
#   'COP': 4949.021939,
#   'CRC': 612.722734,
#   'CUC': 1.08769,
#   'CUP': 28.823784,
#   'CVE': 110.373574,
#   'CZK': 23.867722,
#   'DJF': 193.640484,
#   'DKK': 7.440232,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import json

# %%
json.dumps(response.json(), indent = 4)
# Out:
# '{\n    "success": true,\n    "timestamp": 1674576723,\n    "base": "EUR",\n    "date": "2023-01-24",\n    "rates": {\n        "AED": 3.995122,\n        "AFN": 97.345406,\n        "ALL": 116.254359,\n        "AMD": 431.150732,\n        "ANG": 1.960437,\n        "AOA": 547.296249,\n        "ARS": 200.887962,\n        "AUD": 1.544137,\n        "AWG": 1.957842,\n        "AZN": 1.850545,\n        "BAM": 1.957702,\n        "BBD": 2.19626,\n        "BDT": 115.953063,\n        "BGN": 1.958772,\n        "BHD": 0.410068,\n        "BIF": 2243.360538,\n        "BMD": 1.08769,\n        "BND": 1.435312,\n        "BOB": 7.516294,\n        "BRL": 5.606386,\n        "BSD": 1.08777,\n        "BTC": 4.7518463e-05,\n        "BTN": 88.824577,\n        "BWP": 13.927665,\n        "BYN": 2.745525,\n        "BYR": 21318.723176,\n        "BZD": 2.192496,\n        "CAD": 1.453399,\n        "CDF": 2218.88713,\n        "CHF": 1.005156,\n        "CLF": 0.031624,\n        "CLP": 872.978202,\n        "CNY": 7.3794
# ...

# %%
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "success": true,
#     "timestamp": 1674576723,
#     "base": "EUR",
#     "date": "2023-01-24",
#     "rates": {
#         "AED": 3.995122,
#         "AFN": 97.345406,
#         "ALL": 116.254359,
#         "AMD": 431.150732,
#         "ANG": 1.960437,
#         "AOA": 547.296249,
#         "ARS": 200.887962,
#         "AUD": 1.544137,
#         "AWG": 1.957842,
#         "AZN": 1.850545,
#         "BAM": 1.957702,
#         "BBD": 2.19626,
#         "BDT": 115.953063,
#         "BGN": 1.958772,
#         "BHD": 0.410068,
#         "BIF": 2243.360538,
#         "BMD": 1.08769,
#         "BND": 1.435312,
#         "BOB": 7.516294,
#         "BRL": 5.606386,
#         "BSD": 1.08777,
#         "BTC": 4.7518463e-05,
#         "BTN": 88.824577,
#         "BWP": 13.927665,
#         "BYN": 2.745525,
#         "BYR": 21318.723176,
#         "BZD": 2.192496,
#         "CAD": 1.453399,
#         "CDF": 2218.88713,
#         "CHF": 1.005156,
#         "CLF": 0.031624,
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %%
param_url = url + "?symbols=USD,GBP"

# %%
param_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=USD,GBP'

# %%
response = requests.request("GET", param_url, headers=headers, data = payload)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1674576723,
#  'base': 'EUR',
#  'date': '2023-01-24',
#  'rates': {'USD': 1.08769, 'GBP': 0.883128}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2023-01-24'

# %%
data['rates']
# Out:
# {'USD': 1.08769, 'GBP': 0.883128}

# %%
param_url = url + "?symbols=GBP" + "&" + "base=USD"
param_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/latest?symbols=GBP&base=USD'

# %%
data = requests.request("GET", param_url, headers=headers, data = payload).json()

# %%
data
# Out:
# {'success': True,
#  'timestamp': 1674576723,
#  'base': 'USD',
#  'date': '2023-01-24',
#  'rates': {'GBP': 0.811929}}

# %%
usd_to_gbp = data['rates']['GBP']
usd_to_gbp
# Out:
# 0.811929

# %%
historical_url = "https://api.apilayer.com/exchangerates_data/2016-01-26"
historical_url
# Out:
# 'https://api.apilayer.com/exchangerates_data/2016-01-26'

# %%
response = requests.request("GET", historical_url, headers=headers, data = payload)
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1453852799,
#  'historical': True,
#  'base': 'EUR',
#  'date': '2016-01-26',
#  'rates': {'AED': 3.991061,
#   'AFN': 74.58154,
#   'ALL': 137.965795,
#   'AMD': 530.247142,
#   'ANG': 1.943586,
#   'AOA': 168.999693,
#   'ARS': 14.990112,
#   'AUD': 1.55192,
#   'AWG': 1.948565,
#   'AZN': 1.738253,
#   'BAM': 1.958195,
#   'BBD': 2.173122,
#   'BDT': 85.139638,
#   'BGN': 1.959586,
#   'BHD': 0.409556,
#   'BIF': 1701.160447,
#   'BMD': 1.086561,
#   'BND': 1.550257,
#   'BOB': 7.503896,
#   'BRL': 4.430875,
#   'BSD': 1.086561,
#   'BTC': 0.002759,
#   'BTN': 73.608145,
#   'BWP': 12.59286,
#   'BYR': 22823.99887,
#   'BZD': 2.166505,
#   'CAD': 1.536042,
#   'CDF': 1008.769361,
#   'CHF': 1.104771,
#   'CLF': 0.026732,
#   'CLP': 780.130471,
#   'CNY': 7.136479,
#   'COP': 3643.349976,
#   'CRC': 581.502935,
#   'CUC': 1.086561,
#   'CUP': 1.08504,
#   'CVE': 110.692846,
#   'CZK': 27.049648,
#   'DJF': 193.049679,
#   'DKK': 7.470534,
# ...

# %%
time_period ="https://api.apilayer.com/exchangerates_data/timeseries?start_date=2017-04-26&end_date=2018-04-26&symbols=GBP"
time_period
# Out:
# 'https://api.apilayer.com/exchangerates_data/timeseries?start_date=2017-04-26&end_date=2018-04-26&symbols=GBP'

# %%
data = requests.request("GET", time_period, headers=headers, data = payload).json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timeseries": true,
#     "start_date": "2017-04-26",
#     "end_date": "2018-04-26",
#     "base": "EUR",
#     "rates": {
#         "2017-04-26": {
#             "GBP": 0.849233
#         },
#         "2017-04-27": {
#             "GBP": 0.842886
#         },
#         "2017-04-28": {
#             "GBP": 0.841437
#         },
#         "2017-04-29": {
#             "GBP": 0.841437
#         },
#         "2017-04-30": {
#             "GBP": 0.843718
#         },
#         "2017-05-01": {
#             "GBP": 0.846159
#         },
#         "2017-05-02": {
#             "GBP": 0.845241
#         },
#         "2017-05-03": {
#             "GBP": 0.846057
#         },
#         "2017-05-04": {
#             "GBP": 0.849792
#         },
#         "2017-05-05": {
#             "GBP": 0.847757
#         },
#         "2017-05-06": {
#             "GBP": 0.847757
#         },
#         "2017-05-07": {
#             "GBP": 0.845862
#         },
# ...

# %%
# Gathering input parameters from the user
date = input("Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): ")
base = input("Convert from (currency): ")
curr = input("Convert to (currency): ")
quan = float(input("How much {} do you want to convert: ".format(base)))

# Constructing the URL based on the user parameters and sending a request to the server
convert = url + "/" + date + "?base=" + base + "&symbols=" + curr
response = requests.request("GET", convert, headers=headers, data = payload)

# Displaying the error message, if something went wrong
if(response.ok is False):
    print("\nError {}:".format(response.status_code))
    print(response.json()['error'])

else:
    data = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan,base,result,curr,data['date']))
# Out:
# Please enter the date (in the format 'yyyy-mm-dd' or 'latest'): 2009-07-03
# Convert from (currency): GBP
# Convert to (currency): USD
# How much GBP do you want to convert: 26
#
# 26.0 GBP is equal to 42.518190000000004 USD, based upon exchange rates on 2009-07-03

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site +"?term=the+beatles&country=us"
requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country": "us"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %%
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 16.99,
#             "collectionExplicitness": "notExplicit",
# ...

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][0], indent = 4))
# Out:
# {
#     "wrapperType": "audiobook",
#     "artistId": 160778930,
#     "collectionId": 1439484338,
#     "artistName": "Bob Spitz",
#     "collectionName": "The Beatles (Abridged)",
#     "collectionCensoredName": "The Beatles (Abridged)",
#     "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#     "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#     "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#     "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#     "collectionPrice": 16.99,
#     "collectionExplicitness": "notExplicit",
#     "trackCount": 1,
#     "country": "USA",
#     "currency": "USD",
#     "releaseDate": "2005-11-01T08:00:00Z",
#     "primaryGenreName": "Biographies & Memoirs",
# ...

# %%
info["resultCount"]
# Out:
# 50

# %%
r = requests.get(base_site, params = {"term": "the beatles", "country": "us", "limit": 200})

# %%
r.json()["resultCount"]
# Out:
# 200

# %%
r.json()
# Out:
# {'resultCount': 200,
#  'results': [{'wrapperType': 'audiobook',
#    'artistId': 160778930,
#    'collectionId': 1439484338,
#    'artistName': 'Bob Spitz',
#    'collectionName': 'The Beatles (Abridged)',
#    'collectionCensoredName': 'The Beatles (Abridged)',
#    'artistViewUrl': 'https://books.apple.com/us/author/bob-spitz/id160778930?uo=4',
#    'collectionViewUrl': 'https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg',
#    'collectionPrice': 16.99,
#    'collectionExplicitness': 'notExplicit',
#    'trackCount': 1,
#    'country': 'USA',
#    'currency': 'USD',
#    'releaseDate': '2005-11-01T08:00:00Z',
# ...

# %%
import pandas as pd

# %%
songs_df = pd.DataFrame(info['results'])
songs_df
# Out:
#    wrapperType   artistId  collectionId           artistName  \
# 0    audiobook  160778930    1439484338            Bob Spitz
# 1        track    5621730    1025317255     Devendra Banhart
# 2        track  829356035    1440844129         Rae Sremmurd
# 3    audiobook  434226404    1648540692         David Browne
# 4        track     136975    1441133100          The Beatles
# 5        track     157458     282495289      Daniel Johnston
# 6        track     136975    1441133180          The Beatles
# 7        track     157458    1558590212      Daniel Johnston
# 8        track     136975    1441133180          The Beatles
# 9        track     136975    1441133180          The Beatles
# 10       track     136975    1441133100          The Beatles
# 11       track     136975    1441133180          The Beatles
# 12   audiobook  511539599     511539450  Michael R. Frontani
# 13   audiobook  310801194    1454533897         Paul Charles
# ...

# %%
songs_df.to_csv("songs_info.csv")

# %%
songs_df.to_excel("songs_info.xlsx")

# %%
base_site = "https://jobs.github.com/positions.json"

# %%
r = requests.get(base_site, params = {"description": "data science", "location": "los angeles"})
r.status_code
# Out:
# 404
