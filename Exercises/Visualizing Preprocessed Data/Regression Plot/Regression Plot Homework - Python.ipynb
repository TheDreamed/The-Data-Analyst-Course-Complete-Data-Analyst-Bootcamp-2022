# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_insurance_sweden = pd.read_csv("regression_auto_insurance_sweden.csv")
df_insurance_sweden
# Out:
#     Claims  Payment
# 0      108    392.5
# 1       19     46.2
# 2       13     15.7
# 3      124    422.2
# 4       40    119.4
# ..     ...      ...
# 58       9     87.4
# 59      31    209.8
# 60      14     95.5
# 61      53    244.6
# 62      26    187.5
#
# [63 rows x 2 columns]

# %%
#plt.figure(figsize = (10,8))
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = 'Claims',
            y = 'Payment',
            data = df_insurance_sweden,
            scatter_kws = {'color': 'k'},
            line_kws = {'color': 'red'})

plt.xlabel("Number of Claims")
plt.ylabel("Number of Payments")
plt.title("Effects of Claims to the Number of Payments on Auto Insurance in Sweden", fontsize = 14, weight = 'bold')
plt.show()

# %%
plt.savefig("Effects of Claims to the Number of Payments on Auto Insurance in Sweden")
